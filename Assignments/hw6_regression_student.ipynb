# %% [markdown]
# # Regression Homework
#
# We will use a synthetic dataset to try to predict a students test score based on various other metrics.
#
# ### Variables:
# - Hours Studied: The total number of hours spent studying by each student.
# - Previous Scores: The scores obtained by students in previous tests.
# - Extracurricular Activities: Whether the student participates in extracurricular activities (Yes or No) *CATEGORICAL*
# - Sleep Hours: The average number of hours of sleep the student had per day.
# - Sample Question Papers Practiced: The number of sample question papers the student practiced.
#
#
# ### Target Variable:
#
# Performance Index: A measure of the overall performance of each student. The performance index represents the student's academic performance and has been rounded to the nearest integer. The index ranges from 10 to 100, with higher values indicating better performance.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
from pandas.plotting import scatter_matrix
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# read in the student_performance.csv file
df = pd.read_csv('student_performance.csv')
# display the first 5 rows of the dataframe
print(df.head())
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Practice Questions  Performance Index
# 0                   1                 91
# 1                   2                 65
# 2                   2                 45
# 3                   2                 36
# 4                   5                 66

# %%
# rename the columns to be one word and lowercase
df.columns = [col.lower().replace(' ', '_') for col in df.columns]
# display the first 5 rows of the dataframe
print(df.head())
# Out:
#    hours_studied  previous_scores extracurricular_activities  sleep_hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    practice_questions  performance_index
# 0                   1                 91
# 1                   2                 65
# 2                   2                 45
# 3                   2                 36
# 4                   5                 66

# %%
df.dtypes
# Out:
# hours_studied                  int64
# previous_scores                int64
# extracurricular_activities    object
# sleep_hours                    int64
# practice_questions             int64
# performance_index              int64
# dtype: object

# %%
# seborn scatter matrix of the dataframe
scatter_matrix(df, figsize=(10, 10))
plt.show()

# %% [markdown]
# ### CODE
# Pick two predictors that visually seem to have some correlation witht the target variable, performance_index and generate a visualization that highlights this.
#
# ### ANALYSIS
# Give an initial impression on whether the relationship will be positive or negative. Does it appear linear (straight line) or potentially polynomial (curvatures)?

# %% [markdown]
# ### CODE
# Choose a single predictor and run a logistic analysis on the target.
#
# ### ANALYSIS
# Interpret the output using the correct language for the metrics. Talk about R-squared and exactly what that means, as well as the coefficients, p-value, and F1.

# %% [markdown]
# ### CODE
#
# Use all the predictors in a linear regression model. You'll need to account for the categorical column, extracurricular_activities
#
# ### ANALYSIS
#
# Interpret the resulting output, again focusing on our important metrics. Be sure to note how to interpret the categorical column value, ie, which is the baseline class (const) and what does the coef for extracurricular_activities mean exactly.
#
# ### ANALYSIS
#
# Were all the predictors statistically significant? Are there any you would drop from the model?

# %% [markdown]
# ### CODE
#
# Make a couple prediction using your model, changing the input values.
#
# ### Analysis
#
# Does your prediction "make sense" and seem accurate.
