# %%
# !pip install requests pandas seaborn boto3

# %%
import requests

# URL of the dataset (Iris dataset from UCI Machine Learning Repository)
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

# Send a GET request to download the data
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    with open("iris.csv", "wb") as file:
        file.write(response.content)
    print("Data downloaded successfully!")
else:
    print(f"Failed to download data. Status code: {response.status_code}")

# %%
from urllib.request import urlretrieve

# URL of the dataset
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

# Download the file
urlretrieve(url, "iris_urllib.csv")
print("Data downloaded successfully!")

# %%
import requests

# API endpoint and API key (sign up at https://openweathermap.org/api to get your own API key)
api_key = "your_api_key_here"  # Replace with your API key
city = "Pittsburgh"
url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}"

# Send a GET request to the API
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()  # Assuming the API returns JSON data
    print("Data downloaded successfully!")
    print(data)  # Display the downloaded data
else:
    print(f"Failed to download data. Status code: {response.status_code}")

# %%
# !pip install gdown

#https://drive.google.com/file/d/1SFHl0CbUS-EJ64exFQBLy9O-0AnzUOLs/view?usp=sharing

import gdown

# Google Drive file ID (example: Titanic dataset)
file_id = "1SFHl0CbUS-EJ64exFQBLy9O-0AnzUOLs"  # Replace with your file ID
url = f"https://drive.google.com/uc?id={file_id}"

# Download the file
output = "FireIncidentsDownloaded.csv"
gdown.download(url, output, quiet=False)
print("Data downloaded successfully!")

# %%
import boto3

# Initialize the S3 client
s3 = boto3.client('s3')

# Specify the bucket name and file key
bucket_name = "your_bucket_name"
file_key = "your_file_key.csv"

# Download the file
s3.download_file(bucket_name, file_key, "data.csv")
print("Data downloaded successfully!")

# %%
import pandas as pd

# Load a built-in dataset
df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv")

# Display the first few rows
df.head()
