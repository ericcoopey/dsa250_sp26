# %% [markdown]
# ***Graphing Lab 1***
#
# We are going to use a dataset on car MPG
#
# https://raw.githubusercontent.com/MainakRepositor/Datasets/refs/heads/master/auto-mpg.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
from pandas.plotting import scatter_matrix
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
cars = pd.read_csv(
    'https://raw.githubusercontent.com/MainakRepositor/Datasets/refs/heads/master/auto-mpg.csv'
)

#set the cylinders, origins and model year as categorical variables
cars['cylinders'] = cars['cylinders'].astype('category')
cars['origin'] = cars['origin'].astype('category')
cars['model year'] = cars['model year'].astype('category')


#show column types
print(cars.dtypes)
# Out:
# mpg              float64
# cylinders       category
# displacement     float64
# horsepower        object
# weight             int64
# acceleration     float64
# model year      category
# origin          category
# car name          object
# dtype: object

# %%
cars.head()
# Out:
#     mpg cylinders  displacement horsepower  weight  acceleration model year  \
# 0  18.0         8         307.0        130    3504          12.0         70
# 1  15.0         8         350.0        165    3693          11.5         70
# 2  18.0         8         318.0        150    3436          11.0         70
# 3  16.0         8         304.0        150    3433          12.0         70
# 4  17.0         8         302.0        140    3449          10.5         70
#
#   origin                   car name
# 0      1  chevrolet chevelle malibu
# 1      1          buick skylark 320
# 2      1         plymouth satellite
# 3      1              amc rebel sst
# 4      1                ford torino

# %% [markdown]
# **Challenge 1**
#
# EITHER:
# 1) Produce a histogram on one numberical variable, try to alter the bin size
#
# 2) Produce a pie chart of a categorical variable

# %% [markdown]
# **Challenge 2**
#
# Choose a numerical column and produce a boxplot of it.
#
# Extra challenge: using a figure and axis, create 2 or more boxplots with different axis

# %% [markdown]
# **Challenge 3**
#
# Choose a pair of numeric variables and generate a scatterplot. Clearly label your axis.
#
# Extra: once again, try figure/axis to create a couple

# %% [markdown]
# **Challenge 4**
#
# Take your scatterplot from 3, and add a THIRD variable, this time a categorical, as a color or shape
